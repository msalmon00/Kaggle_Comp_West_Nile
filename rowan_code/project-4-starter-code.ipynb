# %% [markdown]
# ## Project 4 - Kaggle Competition Starter Code (West Nile Virus Detection)

# %%
import pandas as pd
import numpy as np

# %%
weather = pd.read_csv("../assets/weather.csv")
weather.head()
# Out:
#    Station        Date  Tmax  Tmin Tavg Depart  DewPoint WetBulb Heat Cool  \
# 0        1  2007-05-01    83    50   67     14        51      56    0    2
# 1        2  2007-05-01    84    52   68      M        51      57    0    3
# 2        1  2007-05-02    59    42   51     -3        42      47   14    0
# 3        2  2007-05-02    60    43   52      M        42      47   13    0
# 4        1  2007-05-03    66    46   56      2        40      48    9    0
#
#      ...    CodeSum Depth Water1 SnowFall PrecipTotal StnPressure SeaLevel  \
# 0    ...                0      M      0.0        0.00       29.10    29.82
# 1    ...                M      M        M        0.00       29.18    29.82
# 2    ...         BR     0      M      0.0        0.00       29.38    30.09
# 3    ...      BR HZ     M      M        M        0.00       29.44    30.08
# 4    ...                0      M      0.0        0.00       29.39    30.12
#
#   ResultSpeed ResultDir  AvgSpeed
# 0         1.7        27       9.2
# 1         2.7        25       9.6
# 2        13.0         4      13.4
# 3        13.3         2      13.4
# 4        11.7         7      11.9
#
# [5 rows x 22 columns]

# %%
weather = weather[weather.Station == 1]

# %%
weather.columns
# Out:
# Index([u'Station', u'Date', u'Tmax', u'Tmin', u'Tavg', u'Depart', u'DewPoint',
#        u'WetBulb', u'Heat', u'Cool', u'Sunrise', u'Sunset', u'CodeSum',
#        u'Depth', u'Water1', u'SnowFall', u'PrecipTotal', u'StnPressure',
#        u'SeaLevel', u'ResultSpeed', u'ResultDir', u'AvgSpeed'],
#       dtype='object')

# %%
weather.drop(["CodeSum","Depth","Station", "SnowFall", "Water1"], axis=1, inplace=True)

# %%
weather.columns
# Out:
# Index([u'Date', u'Tmax', u'Tmin', u'Tavg', u'Depart', u'DewPoint', u'WetBulb',
#        u'Heat', u'Cool', u'Sunrise', u'Sunset', u'PrecipTotal', u'StnPressure',
#        u'SeaLevel', u'ResultSpeed', u'ResultDir', u'AvgSpeed'],
#       dtype='object')

# %%
def eda(dataframe): #Ritkas code chunk to check quality of data
    print "missing values \n", dataframe.isnull().sum() #shows total amount of null values for each column
    print "dataframe types \n", dataframe.dtypes
    print "dataframe shape \n", dataframe.shape     
    print "dataframe describe \n", dataframe.describe()
    print "dataframe length =", len(dataframe) #length of the dataframe
    print "duplicates", dataframe.duplicated().sum() # added this to duplicates in the data
    for item in dataframe:
        print item
        print dataframe[item].nunique()
        
eda(weather)
# Out:
# missing values
# Date           0
# Tmax           0
# Tmin           0
# Tavg           0
# Depart         0
# DewPoint       0
# WetBulb        0
# Heat           0
# Cool           0
# Sunrise        0
# Sunset         0
# PrecipTotal    0
# StnPressure    0
# SeaLevel       0
# ResultSpeed    0
# ResultDir      0
# AvgSpeed       0
# dtype: int64
# dataframe types
# Date           datetime64[ns]
# Tmax                    int64
# Tmin                    int64
# Tavg                  float64
# Depart                float64
# DewPoint                int64
# WetBulb               float64
# Heat                  float64
# Cool                  float64
# Sunrise                object
# Sunset                 object
# PrecipTotal           float64
# StnPressure            object
# SeaLevel               object
# ResultSpeed           float64
# ResultDir               int64
# AvgSpeed               object
# dtype: object
# dataframe shape
# (1472, 17)
# dataframe describe
#              Tmax         Tmin         Tavg       Depart     DewPoint  \
# count  1472.00000  1472.000000  1472.000000  1472.000000  1472.000000
# mean     75.97894    56.730978    66.606658     1.954484    53.377717
# std      11.50315    10.347907    10.511437     6.841110    10.670263
# min      42.00000    29.000000    36.000000   -17.000000    22.000000
# 25%      68.00000    49.000000    60.000000    -3.000000    46.000000
# 50%      78.00000    58.000000    68.000000     2.000000    54.000000
# 75%      85.00000    65.000000    75.000000     7.000000    61.250000
# max     103.00000    82.000000    93.000000    23.000000    75.000000
#
#            WetBulb         Heat         Cool  PrecipTotal  ResultSpeed  \
# count  1472.000000  1472.000000  1472.000000  1472.000000  1472.000000
# mean     59.051630     3.631114     5.237772     0.134538     6.987092
# std       9.320856     6.133829     5.899382     0.421066     3.586353
# min      32.000000     0.000000     0.000000     0.000000     0.100000
# 25%      53.000000     0.000000     0.000000     0.000000     4.400000
# 50%      60.000000     0.000000     3.000000     0.000000     6.400000
# 75%      66.000000     5.000000    10.000000     0.060000     9.100000
# max      78.000000    29.000000    28.000000     6.860000    24.100000
#
#          ResultDir
# count  1472.000000
# mean     17.656250
# std      10.222077
# min       1.000000
# 25%       7.000000
# 50%      19.500000
# 75%      26.000000
# max      36.000000
# dataframe length = 1472
# duplicates 0
# Date
# 1472
# Tmax
# 60
# Tmin
# 53
# Tavg
# 56
# Depart
# 41
# DewPoint
# 54
# WetBulb
# 47
# Heat
# 30
# Cool
# 27
# Sunrise
# 121
# Sunset
# 118
# PrecipTotal
# 125
# StnPressure
# 94
# SeaLevel
# 97
# ResultSpeed
# 180
# ResultDir
# 36
# AvgSpeed
# 164

# %%
weather[weather['Tavg'] == 'M']
weather.ix[weather.Tavg == "M", "Tavg"] = ((weather.Tmax + weather.Tmin)/2)
#Mike's piece of code for imputing missing values, this time replacing missing values in Tavg 
# with the average of TMax and TMin

# %%
weather.ix[weather.WetBulb == "M", "WetBulb"] = ((weather.Tavg + weather.DewPoint)/2)

# %%
weather.Date = pd.to_datetime(weather["Date"])
weather['Tavg']= weather['Tavg'].astype('float')
weather['Heat']= weather['Heat'].astype('float')
weather['Cool']= weather['Cool'].astype('float')
weather['Depart']= weather['Depart'].astype('float')
weather['WetBulb']= weather['WetBulb'].astype('float')
weather['SeaLevel']= weather['SeaLevel'].astype('float')
weather['StnPressure']= weather['StnPressure'].astype('float')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-192-132d440e71e3> in <module>()
#       5 weather['Depart']= weather['Depart'].astype('float')
#       6 weather['WetBulb']= weather['WetBulb'].astype('float')
# ----> 7 weather['SeaLevel']= weather['SeaLevel'].astype('float')
#       8 weather['StnPressure']= weather['StnPressure'].astype('float')
#
# /Users/rowan/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in astype(self, dtype, copy, raise_on_error, **kwargs)
#    3052         # else, only a single dtype is given
#    3053         new_data = self._data.astype(dtype=dtype, copy=copy,
# -> 3054                                      raise_on_error=raise_on_error, **kwargs)
#    3055         return self._constructor(new_data).__finalize__(self)
#    3056
#
# /Users/rowan/anaconda/lib/python2.7/site-packages/pandas/core/internals.pyc in astype(self, dtype, **kwargs)
#    3187
#    3188     def astype(self, dtype, **kwargs):
# -> 3189         return self.apply('astype', dtype=dtype, **kwargs)
#    3190
#    3191     def convert(self, **kwargs):
#
# /Users/rowan/anaconda/lib/python2.7/site-packages/pandas/core/internals.pyc in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#    3054
#    3055             kwargs['mgr'] = self
# -> 3056             applied = getattr(b, f)(**kwargs)
#    3057             result_blocks = _extend_blocks(applied, result_blocks)
#    3058
#
# /Users/rowan/anaconda/lib/python2.7/site-packages/pandas/core/internals.pyc in astype(self, dtype, copy, raise_on_error, values, **kwargs)
#     459                **kwargs):
#     460         return self._astype(dtype, copy=copy, raise_on_error=raise_on_error,
# --> 461                             values=values, **kwargs)
#     462
#     463     def _astype(self, dtype, copy=False, raise_on_error=True, values=None,
#
# /Users/rowan/anaconda/lib/python2.7/site-packages/pandas/core/internals.pyc in _astype(self, dtype, copy, raise_on_error, values, klass, mgr, **kwargs)
#     502
#     503                 # _astype_nansafe works fine with 1-d only
# --> 504                 values = _astype_nansafe(values.ravel(), dtype, copy=True)
#     505                 values = values.reshape(self.shape)
#     506
#
# /Users/rowan/anaconda/lib/python2.7/site-packages/pandas/types/cast.pyc in _astype_nansafe(arr, dtype, copy)
#     535
#     536     if copy:
# --> 537         return arr.astype(dtype)
#     538     return arr.view(dtype)
#     539
#
# ValueError: could not convert string to float: M

# %%
weather.PrecipTotal = weather.PrecipTotal.str.replace(r'T', '0').astype(float)

# %%
weather.corr()
# Out:
#                  Tmax      Tmin      Tavg    Depart  DewPoint   WetBulb  \
# Tmax         1.000000  0.851965  0.966207  0.683311  0.803170  0.904997
# Tmin         0.851965  1.000000  0.957567  0.578054  0.913338  0.953239
# Tavg         0.966207  0.957567  1.000000  0.658357  0.888062  0.963578
# Depart       0.683311  0.578054  0.658357  1.000000  0.554093  0.612308
# DewPoint     0.803170  0.913338  0.888062  0.554093  1.000000  0.973394
# WetBulb      0.904997  0.953239  0.963578  0.612308  0.973394  1.000000
# Heat        -0.867658 -0.820863 -0.878719 -0.525621 -0.783307 -0.854771
# Cool         0.819434  0.852695  0.868146  0.626541  0.767900  0.828149
# PrecipTotal  0.041751  0.127415  0.085286  0.065823  0.228370  0.167051
# ResultSpeed -0.187049 -0.112225 -0.158167  0.020585 -0.191599 -0.181671
# ResultDir    0.034667  0.009511  0.024257  0.107721  0.013438  0.018352
#
#                  Heat      Cool  PrecipTotal  ResultSpeed  ResultDir
# Tmax        -0.867658  0.819434     0.041751    -0.187049   0.034667
# Tmin        -0.820863  0.852695     0.127415    -0.112225   0.009511
# Tavg        -0.878719  0.868146     0.085286    -0.158167   0.024257
# Depart      -0.525621  0.626541     0.065823     0.020585   0.107721
# DewPoint    -0.783307  0.767900     0.228370    -0.191599   0.013438
# WetBulb     -0.854771  0.828149     0.167051    -0.181671   0.018352
# Heat         1.000000 -0.525949    -0.065560     0.207425   0.068331
# Cool        -0.525949  1.000000     0.083796    -0.066151   0.114267
# PrecipTotal -0.065560  0.083796     1.000000    -0.029755   0.055047
# ResultSpeed  0.207425 -0.066151    -0.029755     1.000000   0.094227
# ResultDir    0.068331  0.114267     0.055047     0.094227   1.000000

# %%
weather[weather.SeaLevel == 'M']
# Out:
#            Date  Tmax  Tmin  Tavg  Depart  DewPoint  WetBulb  Heat  Cool  \
# 832  2009-06-18    80    61  71.0     1.0        63     67.0   0.0   6.0
# 994  2009-09-07    77    59  68.0     1.0        59     62.0   0.0   3.0
# 1732 2011-09-08    75    57  66.0     0.0        53     59.0   0.0   1.0
# 1756 2011-09-20    74    49  62.0     0.0        54     58.0   3.0   0.0
# 2090 2012-09-03    88    71  80.0    12.0        70     73.0   0.0  15.0
#
#      Sunrise Sunset  PrecipTotal StnPressure SeaLevel  ResultSpeed  ResultDir  \
# 832     0416   1929         0.12       29.08        M          6.7         16
# 994     0523   1817         0.00       29.39        M          5.8          3
# 1732    0524   1815         0.00       29.34        M         13.0          2
# 1756    0537   1753         0.00       29.26        M          7.3         18
# 2090    0519   1824         0.00       29.17        M          4.6          6
#
#      AvgSpeed
# 832       7.9
# 994       4.0
# 1732     13.4
# 1756      7.3
# 2090      4.4

# %%
weather

# %%
import pandas as pd
import numpy as np

# %%
weather = pd.read_csv("../assets/clean_weather.csv", index_col=0)
train = pd.read_csv("../assets/clean_train.csv", index_col=0)

# %%
weather.head()
# Out:
#          Date  Tmax  Tmin  Tavg  Depart  DewPoint  WetBulb  Heat  Cool  \
# 0  2007-05-01    83    50  67.0    14.0        51     56.0   0.0   2.0
# 2  2007-05-02    59    42  51.0    -3.0        42     47.0  14.0   0.0
# 4  2007-05-03    66    46  56.0     2.0        40     48.0   9.0   0.0
# 6  2007-05-04    66    49  58.0     4.0        41     50.0   7.0   0.0
# 8  2007-05-05    66    53  60.0     5.0        38     49.0   5.0   0.0
#
#    Sunrise  Sunset PrecipTotal  StnPressure  SeaLevel  ResultSpeed  ResultDir  \
# 0      448    1849        0.00        29.10     29.82          1.7         27
# 2      447    1850        0.00        29.38     30.09         13.0          4
# 4      446    1851        0.00        29.39     30.12         11.7          7
# 6      444    1852           T        29.31     30.05         10.4          8
# 8      443    1853           T        29.40     30.10         11.7          7
#
#    AvgSpeed
# 0       9.2
# 2      13.4
# 4      11.9
# 6      10.8
# ...

# %%
train.head()
# Out:
#          Date                 Species  Trap   Latitude  Longitude  \
# 0  2007-05-29  CULEX PIPIENS/RESTUANS  T002  41.954690 -87.800991
# 1  2007-05-29          CULEX RESTUANS  T002  41.954690 -87.800991
# 2  2007-05-29          CULEX RESTUANS  T007  41.994991 -87.769279
# 3  2007-05-29  CULEX PIPIENS/RESTUANS  T015  41.974089 -87.824812
# 4  2007-05-29          CULEX RESTUANS  T015  41.974089 -87.824812
#
#    NumMosquitos  WnvPresent    Year Parent_Trap  Is_Satellite  Mos_WNV_Prob  \
# 0           1.0         0.0  2007.0        T002           0.0      0.058808
# 1           1.0         0.0  2007.0        T002           0.0      0.020059
# 2           1.0         0.0  2007.0        T007           0.0      0.020059
# 3           1.0         0.0  2007.0        T015           0.0      0.058808
# 4           4.0         0.0  2007.0        T015           0.0      0.020059
#
#    Trap_Ever_Wnv  Num_Years_Trap_WNV_Detection  \
# 0            1.0                             4
# ...

# %%
train_weather = pd.merge(["weather", "train"], left_on= "Date", right_on= "Date")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-cfd3084350fd> in <module>()
# ----> 1 train_weather = pd.merge(["weather", "train"], left_on= "Date", right_on= "Date")
#
# TypeError: merge() takes at least 2 arguments (3 given)

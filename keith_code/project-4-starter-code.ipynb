# %% [markdown]
# ## Project 4 - Kaggle Competition Starter Code (West Nile Virus Detection)

# %%
import pandas as pd

# %%
df = pd.read_csv("../assets/clean_train.csv", index_col=0)

# %%
df.head()
# Out:
#          Date                 Species  Trap   Latitude  Longitude  \
# 0  2007-05-29  CULEX PIPIENS/RESTUANS  T002  41.954690 -87.800991
# 1  2007-05-29          CULEX RESTUANS  T002  41.954690 -87.800991
# 2  2007-05-29          CULEX RESTUANS  T007  41.994991 -87.769279
# 3  2007-05-29  CULEX PIPIENS/RESTUANS  T015  41.974089 -87.824812
# 4  2007-05-29          CULEX RESTUANS  T015  41.974089 -87.824812
#
#    NumMosquitos  WnvPresent    Year Parent_Trap  Is_Satellite  Mos_WNV_Prob  \
# 0           1.0         0.0  2007.0        T002           0.0      0.058808
# 1           1.0         0.0  2007.0        T002           0.0      0.020059
# 2           1.0         0.0  2007.0        T007           0.0      0.020059
# 3           1.0         0.0  2007.0        T015           0.0      0.058808
# 4           4.0         0.0  2007.0        T015           0.0      0.020059
#
#    Trap_Ever_Wnv  Num_Years_Trap_WNV_Detection  \
# 0            1.0                             4
# ...

# %%
df.shape
# Out:
# (8475, 16)

# %%
df.Species.value_counts()
# Out:
# CULEX PIPIENS/RESTUANS    3826
# CULEX RESTUANS            2393
# CULEX PIPIENS             1950
# CULEX TERRITANS            216
# CULEX SALINARIUS            83
# CULEX TARSALIS               6
# CULEX ERRATICUS              1
# Name: Species, dtype: int64

# %%
df.Species.nunique()
# Out:
# 7

# %%
import pandas_profiling as pdp
pdp.ProfileReport(df)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

# %%
df.Trap.head
# Out:
# 0      002
# 1      002
# 2      007
# 3      015
# 4      015
# 5      045
# 6      046
# 7      048
# 8      048
# 9      049
# 10     050
# 11     054
# 12     054
# 13     086
# 14     086
# 15     091
# 16     094
# 17     096
# 18     096
# 19     129
# 20     129
# 21     143
# 22     148
# 23     153
# 24     159
# 25     002
# 26     002
# 27     002
# 28     009
# 29     011
#       ...
# 120    050
# 121    051
# 122    085
# 123    086
# 124    086
# 125    088
# 126    090
# 127    090
# 128    090
# 129    096
# 130    129
# 131    129
# 132    135
# 133    135
# 134    135
# 135    141
# 136    141
# 137    142
# 138    143
# 139    143
# 140    145
# 141    146
# 142    147
# 143    148
# 144    148
# 145    150
# 146    151
# 147    151
# 148    158
# 149    158
# Name: Trap, dtype: object

# %%
#Created a dataframe with only species to further analyse
species = df['Species']

# %%
pd.get_dummies(species, columns=['species'])
# Out:
#       CULEX ERRATICUS  CULEX PIPIENS  CULEX PIPIENS/RESTUANS  CULEX RESTUANS  \
# 0                   0              0                       1               0
# 1                   0              0                       0               1
# 2                   0              0                       0               1
# 3                   0              0                       1               0
# 4                   0              0                       0               1
# 5                   0              0                       0               1
# 6                   0              0                       0               1
# 7                   0              0                       1               0
# 8                   0              0                       0               1
# 9                   0              0                       0               1
# 10                  0              0                       1               0
# ...

# %%
# colors #ff0000 - red, #ffe500 - yellow, #7fff00 - neon green, #00e1ff - light blue

# %%
#X = df.Species
#df[['CULEX ERRATICUS','CULEX ERRATICUS','CULEX PIPIENS/RESTUANS','CULEX RESTUANS','CULEX SALINARIUS','CULEX TARSALIS','CULEX TERRITANS']]
#X.head()

# %%
X = df.s_num
X.head()
# Out:
# 0    2
# 1    3
# 2    3
# 3    2
# 4    3
# Name: s_num, dtype: int64

# %%
# How can I distinguish one species from another?? All I could come up with was to number them 0-6
df['s_num'] = [0 if x =='CULEX ERRATICUS' else 1 if x == 'CULEX PIPIENS' else 2 if x == 'CULEX PIPIENS/RESTUANS' else 3 if x == 'CULEX RESTUANS' else 4 if x == 'CULEX SALINARIUS' else 5 if x == 'CULEX TARSALIS' else 6 for x in df.Species]

# %%
#s_num = species number
y = df.Trap

# %%
y.head()
# Out:
# 0    002
# 1    002
# 2    007
# 3    015
# 4    015
# Name: Trap, dtype: object

# %%
#df['Traps'] = df['Trap'].astype(float)

# %%
#mydf['CigarNum'] = mydf['Cigarettes'].apply(numcigar.get).astype(float)

# %%
df[['Trap']] = df[['Trap']].replace('[/T,]','',regex=True)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.20)

# %%
from sklearn.neighbors import KNeighborsClassifier #import KNeighborsClassifier

# %%
knn = KNeighborsClassifier(n_neighbors = 1)
knn.fit(X_train, y_train)
# Out:
# /Users/keithfitzhugh/anaconda/lib/python2.7/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-184-7d0da873e6eb> in <module>()
#       1 knn = KNeighborsClassifier(n_neighbors = 1)
# ----> 2 knn.fit(X_train, y_train)
#
# /Users/keithfitzhugh/anaconda/lib/python2.7/site-packages/sklearn/neighbors/base.pyc in fit(self, X, y)
#     759         """
#     760         if not isinstance(X, (KDTree, BallTree)):
# --> 761             X, y = check_X_y(X, y, "csr", multi_output=True)
#     762
#     763         if y.ndim == 1 or y.ndim == 2 and y.shape[1] == 1:
#
# ...

# %%
#newdf = pd.get_dummies(df, columns=['Species'],)

# %%
#newdf.head()
# Out:
#          Date  Trap   Latitude  Longitude  NumMosquitos  WnvPresent    Year  \
# 0  2007-05-29  T002  41.954690 -87.800991           1.0         0.0  2007.0
# 1  2007-05-29  T002  41.954690 -87.800991           1.0         0.0  2007.0
# 2  2007-05-29  T007  41.994991 -87.769279           1.0         0.0  2007.0
# 3  2007-05-29  T015  41.974089 -87.824812           1.0         0.0  2007.0
# 4  2007-05-29  T015  41.974089 -87.824812           4.0         0.0  2007.0
#
#   Parent_Trap  Is_Satellite  Mos_WNV_Prob           ...             \
# 0        T002           0.0      0.058808           ...
# 1        T002           0.0      0.020059           ...
# 2        T007           0.0      0.020059           ...
# 3        T015           0.0      0.058808           ...
# 4        T015           0.0      0.020059           ...
#
#    Num_Years_Trap_WNV_Detection  Max_One_Year_Trap_WNV_Detections  \
# 0                             4                               7.0
# ...
